# %%
import os
import pickle

import matplotlib.pyplot as plt
from plot_data import plot, plot_human_normalized #, plot_all_games
import seaborn as sns

# %%
with open(f'data/100k_experiments/final_perf/layer_funct.pickle', mode='rb') as f:
    data_100k = pickle.load(f)
with open(f'data/40M_experiments/final_perf/layer_funct.pickle', mode='rb') as f:
    data_40M = pickle.load(f)

# %%
hp_values = list(data_100k[f'DER_layer_funct'].keys())
colors = zip(hp_values, sns.color_palette("pastel"))
colors = {k:v for (k, v) in colors}

# %%
fig = plot(data_100k[f'DER_layer_funct'], colors, hp_values)

# %%
plt.show()

# %%
hp_values = list(data_40M[f'DER_layer_funct'].keys())
fig = plot(data_40M[f'DER_layer_funct'], colors, hp_values)
plt.show()
